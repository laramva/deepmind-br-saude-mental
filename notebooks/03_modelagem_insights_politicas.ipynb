# %% [markdown]
# # 03 - Modelagem e Insights para Políticas Públicas
#
# Objetivos:
# - Aplicar técnicas de machine learning (clusterização, regressão simples, etc.).
# - Identificar padrões regionais de risco em saúde mental.
# - Gerar insights acionáveis para políticas públicas.

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
