# %% [markdown]
# # 02 - Tratamento dos Dados e Feature Engineering
#
# Objetivos:
# - Tratar valores ausentes.
# - Padronizar colunas e formatos.
# - Criar novas variáveis relevantes (ex.: taxa de internação por 100 mil habitantes).
# - Deixar os dados prontos para análises e modelagem.

# %%
import pandas as pd
import numpy as np
